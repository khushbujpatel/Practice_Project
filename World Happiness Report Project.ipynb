# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.value_counts()
# Out:
# Country                  Region                           Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  Family   Health (Life Expectancy)  Freedom  Trust (Government Corruption)  Generosity  Dystopia Residual
# Afghanistan              Southern Asia                    153             3.575            0.03084         0.31982                   0.30285  0.30335                   0.23414  0.09719                        0.36510     1.95210              1
# Palestinian Territories  Middle East and Northern Africa  108             4.715            0.04394         0.59867                   0.92558  0.66015                   0.24499  0.12905                        0.11251     2.04384              1
# Nicaragua                Latin America and Caribbean      57              5.828            0.05371         0.59325                   1.14184  0.74314                   0.55475  0.19317                        0.27815     2.32407              1
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
features = df.select_dtypes(include='number').drop(columns=['Happiness Score'])
plt.figure(figsize=(16,16))
n=1
for i in features:
    if n<=12:
        plt.subplot(3,4,n)
        sns.boxplot(features[i],palette="Set2_r")
        plt.xlabel(i)
    n+=1
plt.show()

# %% [markdown]
# ## removing outliers
# ### i am removing outliers from 2 columns  which have more outliers and ignoring other coloumns bcz do not want to loose data

# %%
from scipy.stats import zscore
out_features=df[['Standard Error','Trust (Government Corruption)']]
z=np.abs(zscore(out_features))
z
# Out:
#      Standard Error  Trust (Government Corruption)
# 0          0.805926                       2.309652
# 1          0.055889                       0.016480
# 2          0.854487                       2.842774
# 3          0.531526                       1.852081
# 4          0.722845                       1.555725
# ..              ...                            ...
# 153        0.774917                       3.413922
# 154        0.662582                       0.529210
# 155        0.132534                       0.381419
# 156        2.263962                       0.357715
# 157        1.134182                       0.301803
#
# [158 rows x 2 columns]

# %%
df = df[(z<3).all(axis=1)]
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 152  Afghanistan                    Southern Asia             153
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df1 = df.select_dtypes(include='number')
plt.figure(figsize=(20,15), facecolor='white')
plotnumber = 1

for column in df1:
    if plotnumber<=12:
        ax = plt.subplot(4,3,plotnumber)
        sns.distplot(df1[column])
        plt.xlabel(column,fontsize=23)
    plotnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Rank                  -0.015279
# Happiness Score                  0.117430
# Standard Error                   1.194696
# Economy (GDP per Capita)        -0.354766
# Family                          -1.008038
# Health (Life Expectancy)        -0.722205
# Freedom                         -0.396394
# Trust (Government Corruption)    1.278444
# Generosity                       1.013195
# Dystopia Residual               -0.177989
# dtype: float64

# %% [markdown]
# ## removing skewness

# %%
df['Standard Error'] = np.cbrt(df['Standard Error'])
df['Trust (Government Corruption)'] = np.cbrt(df['Trust (Government Corruption)'])

# %%
df.skew()
# Out:
# Happiness Rank                  -0.015279
# Happiness Score                  0.117430
# Standard Error                   0.491044
# Economy (GDP per Capita)        -0.354766
# Family                          -1.008038
# Health (Life Expectancy)        -0.722205
# Freedom                         -0.396394
# Trust (Government Corruption)   -0.080143
# Generosity                       1.013195
# Dystopia Residual               -0.177989
# dtype: float64

# %%
df1 = df.select_dtypes(include='number')
plt.figure(figsize=(20,15), facecolor='white')
plotnumber = 1

for column in df1:
    if plotnumber<=12:
        ax = plt.subplot(4,3,plotnumber)
        sns.distplot(df1[column])
        plt.xlabel(column,fontsize=23)
    plotnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Rank                  -0.015279
# Happiness Score                  0.117430
# Standard Error                   0.491044
# Economy (GDP per Capita)        -0.354766
# Family                          -3.548770
# Health (Life Expectancy)        -1.982327
# Freedom                         -0.396394
# Trust (Government Corruption)   -0.080143
# Generosity                      -0.926437
# Dystopia Residual               -0.177989
# dtype: float64

# %%
df1 = df.select_dtypes(include='number')
plt.figure(figsize=(16,16))
p=1
for i in df1:
    if p<=11:
        plt.subplot(4,3,p)
        sns.regplot(x='Happiness Score',y=i,data=df1,color='r')
        #sns.lmplot(data=df1,x='Happiness Score',y=i,palette='colorblind')
        plt.xlabel("Happiness Score")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
sns.lmplot(data=df1,x='Happiness Score',y='Generosity',palette='colorblind')

# %%
x = df.select_dtypes(include='number').drop(columns=['Happiness Score'])
y = df['Happiness Score']
print("feature dimension=",x.shape)
print('label Dimension',y.shape)
# Out:
# feature dimension= (153, 9)
# label Dimension (153,)

# %%
y.value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 152, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)    Family  \
# 0         -1.722302       -0.931210                  1.395383  1.308640
# 1         -1.700348        0.271122                  1.155940  1.501030
# 2         -1.678394       -1.008565                  1.214816  1.349038
# 3         -1.656440       -0.516148                  1.554241  1.240910
# 4         -1.634486       -0.801726                  1.216875  1.210475
# ..              ...             ...                       ...       ...
# 148        1.614685       -1.243695                 -1.341700 -2.510904
# 149        1.658593       -0.709949                 -1.426023 -2.324755
# 150        1.680546        0.365606                 -0.468784 -1.883084
# 151        1.702500        2.512897                 -2.115829 -2.098464
# 152        1.724454        1.471883                 -1.624232 -3.105370
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS=i
print('maximum r2 score',maxAccu,'on Random_state',maxRS)
# Out:
# maximum r2 score 0.9995124293201388 on Random_state 149

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state = maxRS)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print(LR)
print('R2_Score:',r2_score(y_test,pred_LR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean absolute error:',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# LinearRegression()
# R2_Score: 0.9996410462158656
# R2_score on training data: 99.89102428843437
# mean absolute error: 0.018429339935024307
# Mean Squared Error: 0.0004498923026870313
# root mean squared error: 0.02121066483368759

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('predicted',fontsize=14)
plt.title('Linear Regression',fontsize=14)
plt.show()

# %%
knn = KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print(knn)
print('R2_Score:',r2_score(y_test,pred_knn))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean absolute error:',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# KNeighborsRegressor()
# R2_Score: 0.9990850566564251
# R2_score on training data: 99.76639467558071
# mean absolute error: 0.022154838709677414
# Mean Squared Error: 0.0011467380645161292
# root mean squared error: 0.03386352114763214

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr=rfr.predict(x_test)
pred_train=rfr.predict(x_train)
print(rfr )
print('R2_Score:',r2_score(y_test,pred_rfr ))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean absolute error:',mean_absolute_error(y_test,pred_rfr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rfr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
# RandomForestRegressor()
# R2_Score: 0.9990631129651001
# R2_score on training data: 99.93858296481383
# mean absolute error: 0.022114516129031973
# Mean Squared Error: 0.0011742410419354676
# root mean squared error: 0.03426720067258876

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print(GBR )
print('R2_Score:',r2_score(y_test,pred_GBR ))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean absolute error:',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_Score: 0.9994017748113448
# R2_score on training data: 99.99986478208804
# mean absolute error: 0.019960683020463613
# Mean Squared Error: 0.0007497815026478088
# root mean squared error: 0.027382138387054594

# %% [markdown]
# ## linear regression is performing good and GradientBoostingRegressor also performing good

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('difference between R2 score and cross validation score is:',(r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# [0.94881938 0.97438403 0.91933436 0.98329539 0.99415742]
# 0.9639981126959963
# difference between R2 score and cross validation score is: 3.5642933519869247

# %%
score1 = cross_val_score(GBR,x,y,cv=5)
print(score1)
print(score1.mean())
print('difference between R2 score and cross validation score is:',(r2_score(y_test,pred_GBR)-score1.mean())*100)
# Out:
# [-3.14038144 -0.29723613 -0.4511491  -0.31947044 -1.76951286]
# -1.1955499943914327
# difference between R2 score and cross validation score is: 219.49517692027774

# %% [markdown]
# ## from difference our best performing model is linearreggression model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],'solver':['auto','svd'],'positive':[False,True],'random_state':range(1,20),}
gscv = GridSearchCV(Ridge(),parameters,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': range(1, 20),
#                          'solver': ['auto', 'svd']})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.05,
#  'fit_intercept': False,
#  'positive': False,
#  'random_state': 1,
#  'solver': 'auto'}

# %%
model = Ridge(alpha=0.05,fit_intercept= False,positive= False,random_state= 1,solver= 'auto')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2_Score:',r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9996282845454852
# mean absolute error: 0.018533944404990944
# Mean Squared Error: 0.0007497815026478088
# root mean squared error: 0.021584416974448076

# %%
import pickle
filename = 'worldhappiness.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
import pickle
load_model = pickle.load(open('worldhappiness.pkl','rb'))
result = load_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.96282845454853

# %%
conclusion = pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=['Predicted','original'])
conclusion
# Out:
#                  0         1         2         3        4         5   \
# Predicted  3.657834  5.837214  4.665016  4.666772  7.19159  5.863466
# original   3.678000  5.813000  4.642000  4.681000  7.18700  5.848000
#
#                  6         7        8         9   ...       21        22  \
# Predicted  6.838735  5.239874  5.91059  5.122336  ...  4.23958  6.959074
# original   6.810000  5.212000  5.89000  5.140000  ...  4.25200  6.937000
#
#                  23        24        25        26        27        28  \
# Predicted  3.591345  5.126646  5.442606  6.829525  4.335442  3.996175
# original   3.587000  5.098000  5.474000  6.853000  4.350000  3.989000
#
#                  29        30
# Predicted  5.739354  3.944743
# original   5.759000  3.956000
#
# [2 rows x 31 columns]
